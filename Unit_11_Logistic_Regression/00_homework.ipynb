# %% [markdown]
# ---
# **Understanding the dataset**
#
# The dataset has two columns- value & class
# - `value` : <numerical, int>
# - `class` : <categorical, int>
#
# each row contains a value that belongs to a class [1, 2 or 3].

# %%
import pandas as pd

df = pd.read_csv("./dataset.csv")
df.head()
# Out:
#    length  class
# 0       1      1
# 1       2      1
# 2       2      1
# 3       4      1
# 4       4      1

# %% [markdown]
# ---
# Q1. separate this df into three separate dataframes for each class value.

# %%
# write your code here

# %% [markdown]
# ---
# Q2. How can you use Logistic Regression to classify given values into more than two classes?

# %% [markdown]
# _write your answer here_
# ...

# %% [markdown]
# ---
# Q3. Use logistic regression to predict the class for a given value.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# write your code here
