# %%
import pandas as pd

# Play tennis dataset
data = {
    'Outlook': ['Sunny','Sunny','Overcast','Rain','Rain','Rain','Overcast','Sunny','Sunny','Rain','Sunny','Overcast','Overcast','Rain'],
    'Temperature': ['Hot','Hot','Hot','Mild','Cool','Cool','Mild','Cool','Mild','Mild','Mild','Hot','Mild','Cool'],
    'Humidity': ['High','High','High','High','Normal','Normal','High','High','Normal','Normal','Normal','High','Normal','High'],
    'Wind': ['Weak','Strong','Weak','Weak','Weak','Strong','Strong','Weak','Weak','Weak','Strong','Strong','Weak','Strong'],
    'Play': ['No','No','Yes','Yes','Yes','No','Yes','No','Yes','Yes','Yes','Yes','Yes','No']
}

df = pd.DataFrame(data)
print(f"{df.shape = }")
df
# Out:
# df.shape = (14, 5)
#      Outlook Temperature Humidity    Wind Play
# 0      Sunny         Hot     High    Weak   No
# 1      Sunny         Hot     High  Strong   No
# 2   Overcast         Hot     High    Weak  Yes
# 3       Rain        Mild     High    Weak  Yes
# 4       Rain        Cool   Normal    Weak  Yes
# 5       Rain        Cool   Normal  Strong   No
# 6   Overcast        Mild     High  Strong  Yes
# 7      Sunny        Cool     High    Weak   No
# 8      Sunny        Mild   Normal    Weak  Yes
# 9       Rain        Mild   Normal    Weak  Yes
# 10     Sunny        Mild   Normal  Strong  Yes
# 11  Overcast         Hot     High  Strong  Yes
# 12  Overcast        Mild   Normal    Weak  Yes
# 13      Rain        Cool     High  Strong   No

# %%
# implement a decision tree using adjusted gini index for each node

# %%
# make classifications using the decision tree
outlook =       input("Enter outlook [Sunny, Overcast, Rain]: ")
temperature =   input("Enter temperature [Hot, Mild, Cool]  : ")
humidity =      input("Enter humidity [High, Normal]        : ")
wind =          input("Enter wind [Weak, Strong]            : ")

print(f"(Outlook: {outlook}, Temperature: {temperature}, Humidity: {humidity}, Wind: {wind})")
# Out:
# (Outlook: Sunny, Temperature: Hot, Humidity: High, Wind: Weak)
